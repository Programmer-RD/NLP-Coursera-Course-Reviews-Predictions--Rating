# %%
import pandas as pd

# %%
data = pd.read_csv('./reviews.csv')

# %%
data.head()
# Out:
#    Id                                             Review  Label
# 0   0                               good and interesting      5
# 1   1  This class is very helpful to me. Currently, I...      5
# 2   2  like!Prof and TAs are helpful and the discussi...      5
# 3   3  Easy to follow and includes a lot basic and im...      5
# 4   4  Really nice teacher!I could got the point eazl...      4

# %%
data.drop(['Id'],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                               Review  Label
# 0                               good and interesting      5
# 1  This class is very helpful to me. Currently, I...      5
# 2  like!Prof and TAs are helpful and the discussi...      5
# 3  Easy to follow and includes a lot basic and im...      5
# 4  Really nice teacher!I could got the point eazl...      4

# %%
data.isna().sum()
# Out:
# Review    0
# Label     0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data['Label'].value_counts()
# Out:
# 5    79173
# 4    18054
# 3     5071
# 1     2469
# 2     2251
# Name: Label, dtype: int64

# %%
import numpy as np
to_delete = np.random.choice(data[data['Label'] == 5].index,size=61000,replace=False)

# %%
data.drop(to_delete,axis=0,inplace=True)

# %%
data['Label'].value_counts()
# Out:
# 5    18173
# 4    18054
# 3     5071
# 1     2469
# 2     2251
# Name: Label, dtype: int64

# %%
data.dtypes
# Out:
# Review    object
# Label      int64
# dtype: object

# %%
X = data['Review']
y = data['Label']

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tv = TfidfVectorizer()
cv.fit(X)
X = cv.transform(X)
# X.reshape(-1,1)
# X = pd.DataFrame(X)
y = pd.DataFrame(y)

# %%
from sklearn.metrics import *
from sklearn.model_selection import *
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.4858757062146893

# %%
text = input('Review : ')
text = cv.transform([text])
model.predict(text)
# Out:
# Review : Worst course in the world the worst of the worst I hate the teacher of the course and the teacher is like a nerd and he sucks I hate him and the course the instructions are the worst in the world
# array([5])

# %%
grid = {
#     "n_estimators":[10,100,200,400,800,1600,125,250,500,1250,2500],
    "max_depth":[None,5,10,15,20,25],
    "criterion":["gini","entropy",],
    'splitter':['best','random'],
    "max_features":["auto","sqrt",'log2'],
    "min_samples_leaf":[1,2,4,6,8,10],
}
model_rs = DecisionTreeClassifier()
rs = RandomizedSearchCV(estimator=model_rs,param_distributions=grid,cv=5,n_iter=25,verbose=25)
rs.fit(X_train,y_train)
print(rs.best_estimator_)
print(rs.score(X_test,y_test))
print(rs.best_score_)
import pickle
pickle.dump(model_rs,open('./model_random.pkl','wb'))
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] splitter=best, min_samples_leaf=8, max_features=auto, max_depth=20, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=auto, max_depth=20, criterion=gini, score=0.441, total=   0.1s
# [CV] splitter=best, min_samples_leaf=8, max_features=auto, max_depth=20, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=auto, max_depth=20, criterion=gini, score=0.454, total=   0.1s
# [CV] splitter=best, min_samples_leaf=8, max_features=auto, max_depth=20, criterion=gini
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV]  splitter=best, min_samples_leaf=8, max_features=auto, max_depth=20, criterion=gini, score=0.473, total=   0.1s
# [CV] splitter=best, min_samples_leaf=8, max_features=auto, max_depth=20, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=auto, max_depth=20, criterion=gini, score=0.434, total=   0.1s
# [CV] splitter=best, min_samples_leaf=8, max_features=auto, max_depth=20, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=auto, max_depth=20, criterion=gini, score=0.442, total=   0.1s
# [CV] splitter=random, min_samples_leaf=2, max_features=log2, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=2, max_features=log2, max_depth=20, criterion=entropy, score=0.395, total=   0.0s
# [CV] splitter=random, min_samples_leaf=2, max_features=log2, max_depth=20, criterion=entropy
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.4s remaining:    0.0s
# [CV]  splitter=random, min_samples_leaf=2, max_features=log2, max_depth=20, criterion=entropy, score=0.400, total=   0.0s
# [CV] splitter=random, min_samples_leaf=2, max_features=log2, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=2, max_features=log2, max_depth=20, criterion=entropy, score=0.397, total=   0.0s
# [CV] splitter=random, min_samples_leaf=2, max_features=log2, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=2, max_features=log2, max_depth=20, criterion=entropy, score=0.398, total=   0.0s
# [CV] splitter=random, min_samples_leaf=2, max_features=log2, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=2, max_features=log2, max_depth=20, criterion=entropy, score=0.397, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=auto, max_depth=10, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=4, max_features=auto, max_depth=10, criterion=entropy, score=0.437, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=auto, max_depth=10, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=4, max_features=auto, max_depth=10, criterion=entropy, score=0.469, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=auto, max_depth=10, criterion=entropy
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.6s remaining:    0.0s
# [CV]  splitter=best, min_samples_leaf=4, max_features=auto, max_depth=10, criterion=entropy, score=0.468, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=auto, max_depth=10, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=4, max_features=auto, max_depth=10, criterion=entropy, score=0.425, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=auto, max_depth=10, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=4, max_features=auto, max_depth=10, criterion=entropy, score=0.445, total=   0.0s
# [CV] splitter=best, min_samples_leaf=10, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=best, min_samples_leaf=10, max_features=log2, max_depth=None, criterion=gini, score=0.445, total=   0.0s
# [CV] splitter=best, min_samples_leaf=10, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=best, min_samples_leaf=10, max_features=log2, max_depth=None, criterion=gini, score=0.394, total=   0.0s
# [CV] splitter=best, min_samples_leaf=10, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=best, min_samples_leaf=10, max_features=log2, max_depth=None, criterion=gini, score=0.394, total=   0.0s
# [CV] splitter=best, min_samples_leaf=10, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=best, min_samples_leaf=10, max_features=log2, max_depth=None, criterion=gini, score=0.411, total=   0.0s
# [CV] splitter=best, min_samples_leaf=10, max_features=log2, max_depth=None, criterion=gini
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.9s remaining:    0.0s
# [CV]  splitter=best, min_samples_leaf=10, max_features=log2, max_depth=None, criterion=gini, score=0.395, total=   0.0s
# [CV] splitter=random, min_samples_leaf=2, max_features=sqrt, max_depth=20, criterion=gini
# [CV]  splitter=random, min_samples_leaf=2, max_features=sqrt, max_depth=20, criterion=gini, score=0.425, total=   0.1s
# [CV] splitter=random, min_samples_leaf=2, max_features=sqrt, max_depth=20, criterion=gini
# [CV]  splitter=random, min_samples_leaf=2, max_features=sqrt, max_depth=20, criterion=gini, score=0.422, total=   0.1s
# [CV] splitter=random, min_samples_leaf=2, max_features=sqrt, max_depth=20, criterion=gini
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    1.0s remaining:    0.0s
# [CV]  splitter=random, min_samples_leaf=2, max_features=sqrt, max_depth=20, criterion=gini, score=0.438, total=   0.1s
# [CV] splitter=random, min_samples_leaf=2, max_features=sqrt, max_depth=20, criterion=gini
# [CV]  splitter=random, min_samples_leaf=2, max_features=sqrt, max_depth=20, criterion=gini, score=0.428, total=   0.1s
# [CV] splitter=random, min_samples_leaf=2, max_features=sqrt, max_depth=20, criterion=gini
# [CV]  splitter=random, min_samples_leaf=2, max_features=sqrt, max_depth=20, criterion=gini, score=0.415, total=   0.1s
# [CV] splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    1.2s remaining:    0.0s
# [CV]  splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, score=0.483, total=   0.2s
# [CV] splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, score=0.480, total=   0.2s
# [CV] splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, score=0.484, total=   0.2s
# [CV] splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, score=0.477, total=   0.2s
# [CV] splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, score=0.518, total=   0.2s
# [CV] splitter=random, min_samples_leaf=1, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=random, min_samples_leaf=1, max_features=log2, max_depth=None, criterion=gini, score=0.422, total=   1.8s
# [CV] splitter=random, min_samples_leaf=1, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=random, min_samples_leaf=1, max_features=log2, max_depth=None, criterion=gini, score=0.421, total=   2.0s
# [CV] splitter=random, min_samples_leaf=1, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=random, min_samples_leaf=1, max_features=log2, max_depth=None, criterion=gini, score=0.421, total=   2.2s
# [CV] splitter=random, min_samples_leaf=1, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=random, min_samples_leaf=1, max_features=log2, max_depth=None, criterion=gini, score=0.415, total=   2.3s
# [CV] splitter=random, min_samples_leaf=1, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=random, min_samples_leaf=1, max_features=log2, max_depth=None, criterion=gini, score=0.429, total=   2.2s
# [CV] splitter=best, min_samples_leaf=6, max_features=auto, max_depth=15, criterion=gini
# [CV]  splitter=best, min_samples_leaf=6, max_features=auto, max_depth=15, criterion=gini, score=0.447, total=   0.1s
# [CV] splitter=best, min_samples_leaf=6, max_features=auto, max_depth=15, criterion=gini
# [CV]  splitter=best, min_samples_leaf=6, max_features=auto, max_depth=15, criterion=gini, score=0.454, total=   0.1s
# [CV] splitter=best, min_samples_leaf=6, max_features=auto, max_depth=15, criterion=gini
# [CV]  splitter=best, min_samples_leaf=6, max_features=auto, max_depth=15, criterion=gini, score=0.463, total=   0.1s
# [CV] splitter=best, min_samples_leaf=6, max_features=auto, max_depth=15, criterion=gini
# [CV]  splitter=best, min_samples_leaf=6, max_features=auto, max_depth=15, criterion=gini, score=0.464, total=   0.1s
# [CV] splitter=best, min_samples_leaf=6, max_features=auto, max_depth=15, criterion=gini
# [CV]  splitter=best, min_samples_leaf=6, max_features=auto, max_depth=15, criterion=gini, score=0.509, total=   0.1s
# [CV] splitter=best, min_samples_leaf=8, max_features=auto, max_depth=10, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=8, max_features=auto, max_depth=10, criterion=entropy, score=0.446, total=   0.0s
# [CV] splitter=best, min_samples_leaf=8, max_features=auto, max_depth=10, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=8, max_features=auto, max_depth=10, criterion=entropy, score=0.422, total=   0.0s
# [CV] splitter=best, min_samples_leaf=8, max_features=auto, max_depth=10, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=8, max_features=auto, max_depth=10, criterion=entropy, score=0.502, total=   0.0s
# [CV] splitter=best, min_samples_leaf=8, max_features=auto, max_depth=10, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=8, max_features=auto, max_depth=10, criterion=entropy, score=0.419, total=   0.1s
# [CV] splitter=best, min_samples_leaf=8, max_features=auto, max_depth=10, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=8, max_features=auto, max_depth=10, criterion=entropy, score=0.471, total=   0.1s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, score=0.485, total=   0.4s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, score=0.482, total=   0.3s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, score=0.486, total=   0.3s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, score=0.508, total=   0.4s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, score=0.490, total=   0.3s
# [CV] splitter=best, min_samples_leaf=4, max_features=log2, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=4, max_features=log2, max_depth=10, criterion=gini, score=0.438, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=log2, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=4, max_features=log2, max_depth=10, criterion=gini, score=0.404, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=log2, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=4, max_features=log2, max_depth=10, criterion=gini, score=0.403, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=log2, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=4, max_features=log2, max_depth=10, criterion=gini, score=0.402, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=log2, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=4, max_features=log2, max_depth=10, criterion=gini, score=0.396, total=   0.0s
# [CV] splitter=best, min_samples_leaf=6, max_features=sqrt, max_depth=5, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=6, max_features=sqrt, max_depth=5, criterion=entropy, score=0.436, total=   0.0s
# [CV] splitter=best, min_samples_leaf=6, max_features=sqrt, max_depth=5, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=6, max_features=sqrt, max_depth=5, criterion=entropy, score=0.447, total=   0.0s
# [CV] splitter=best, min_samples_leaf=6, max_features=sqrt, max_depth=5, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=6, max_features=sqrt, max_depth=5, criterion=entropy, score=0.441, total=   0.0s
# [CV] splitter=best, min_samples_leaf=6, max_features=sqrt, max_depth=5, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=6, max_features=sqrt, max_depth=5, criterion=entropy, score=0.432, total=   0.0s
# [CV] splitter=best, min_samples_leaf=6, max_features=sqrt, max_depth=5, criterion=entropy
# [CV]  splitter=best, min_samples_leaf=6, max_features=sqrt, max_depth=5, criterion=entropy, score=0.415, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=log2, max_depth=None, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=4, max_features=log2, max_depth=None, criterion=entropy, score=0.400, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=log2, max_depth=None, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=4, max_features=log2, max_depth=None, criterion=entropy, score=0.395, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=log2, max_depth=None, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=4, max_features=log2, max_depth=None, criterion=entropy, score=0.406, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=log2, max_depth=None, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=4, max_features=log2, max_depth=None, criterion=entropy, score=0.394, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=log2, max_depth=None, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=4, max_features=log2, max_depth=None, criterion=entropy, score=0.399, total=   0.1s
# [CV] splitter=random, min_samples_leaf=4, max_features=log2, max_depth=20, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=log2, max_depth=20, criterion=gini, score=0.397, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=log2, max_depth=20, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=log2, max_depth=20, criterion=gini, score=0.394, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=log2, max_depth=20, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=log2, max_depth=20, criterion=gini, score=0.394, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=log2, max_depth=20, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=log2, max_depth=20, criterion=gini, score=0.399, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=log2, max_depth=20, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=log2, max_depth=20, criterion=gini, score=0.397, total=   0.0s
# [CV] splitter=random, min_samples_leaf=10, max_features=log2, max_depth=25, criterion=gini
# [CV]  splitter=random, min_samples_leaf=10, max_features=log2, max_depth=25, criterion=gini, score=0.416, total=   0.0s
# [CV] splitter=random, min_samples_leaf=10, max_features=log2, max_depth=25, criterion=gini
# [CV]  splitter=random, min_samples_leaf=10, max_features=log2, max_depth=25, criterion=gini, score=0.395, total=   0.0s
# [CV] splitter=random, min_samples_leaf=10, max_features=log2, max_depth=25, criterion=gini
# [CV]  splitter=random, min_samples_leaf=10, max_features=log2, max_depth=25, criterion=gini, score=0.394, total=   0.0s
# [CV] splitter=random, min_samples_leaf=10, max_features=log2, max_depth=25, criterion=gini
# [CV]  splitter=random, min_samples_leaf=10, max_features=log2, max_depth=25, criterion=gini, score=0.394, total=   0.0s
# [CV] splitter=random, min_samples_leaf=10, max_features=log2, max_depth=25, criterion=gini
# [CV]  splitter=random, min_samples_leaf=10, max_features=log2, max_depth=25, criterion=gini, score=0.395, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini, score=0.402, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini, score=0.420, total=   0.1s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini, score=0.405, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini, score=0.414, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini, score=0.411, total=   0.0s
# [CV] splitter=random, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=entropy, score=0.395, total=   0.0s
# [CV] splitter=random, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=entropy, score=0.395, total=   0.0s
# [CV] splitter=random, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=entropy, score=0.397, total=   0.0s
# [CV] splitter=random, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=entropy, score=0.396, total=   0.0s
# [CV] splitter=random, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=entropy, score=0.401, total=   0.0s
# [CV] splitter=best, min_samples_leaf=2, max_features=auto, max_depth=5, criterion=gini
# [CV]  splitter=best, min_samples_leaf=2, max_features=auto, max_depth=5, criterion=gini, score=0.405, total=   0.0s
# [CV] splitter=best, min_samples_leaf=2, max_features=auto, max_depth=5, criterion=gini
# [CV]  splitter=best, min_samples_leaf=2, max_features=auto, max_depth=5, criterion=gini, score=0.408, total=   0.0s
# [CV] splitter=best, min_samples_leaf=2, max_features=auto, max_depth=5, criterion=gini
# [CV]  splitter=best, min_samples_leaf=2, max_features=auto, max_depth=5, criterion=gini, score=0.403, total=   0.0s
# [CV] splitter=best, min_samples_leaf=2, max_features=auto, max_depth=5, criterion=gini
# [CV]  splitter=best, min_samples_leaf=2, max_features=auto, max_depth=5, criterion=gini, score=0.408, total=   0.0s
# [CV] splitter=best, min_samples_leaf=2, max_features=auto, max_depth=5, criterion=gini
# [CV]  splitter=best, min_samples_leaf=2, max_features=auto, max_depth=5, criterion=gini, score=0.437, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini, score=0.466, total=   0.1s
# [CV] splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini, score=0.436, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini, score=0.431, total=   0.0s
# [CV] splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini, score=0.436, total=   0.1s
# [CV] splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=4, max_features=sqrt, max_depth=10, criterion=gini, score=0.469, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=5, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=5, criterion=gini, score=0.397, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=5, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=5, criterion=gini, score=0.401, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=5, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=5, criterion=gini, score=0.404, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=5, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=5, criterion=gini, score=0.412, total=   0.0s
# [CV] splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=5, criterion=gini
# [CV]  splitter=random, min_samples_leaf=4, max_features=sqrt, max_depth=5, criterion=gini, score=0.398, total=   0.0s
# [CV] splitter=best, min_samples_leaf=1, max_features=sqrt, max_depth=15, criterion=gini
# [CV]  splitter=best, min_samples_leaf=1, max_features=sqrt, max_depth=15, criterion=gini, score=0.459, total=   0.1s
# [CV] splitter=best, min_samples_leaf=1, max_features=sqrt, max_depth=15, criterion=gini
# [CV]  splitter=best, min_samples_leaf=1, max_features=sqrt, max_depth=15, criterion=gini, score=0.474, total=   0.1s
# [CV] splitter=best, min_samples_leaf=1, max_features=sqrt, max_depth=15, criterion=gini
# [CV]  splitter=best, min_samples_leaf=1, max_features=sqrt, max_depth=15, criterion=gini, score=0.439, total=   0.1s
# [CV] splitter=best, min_samples_leaf=1, max_features=sqrt, max_depth=15, criterion=gini
# [CV]  splitter=best, min_samples_leaf=1, max_features=sqrt, max_depth=15, criterion=gini, score=0.439, total=   0.1s
# [CV] splitter=best, min_samples_leaf=1, max_features=sqrt, max_depth=15, criterion=gini
# [CV]  splitter=best, min_samples_leaf=1, max_features=sqrt, max_depth=15, criterion=gini, score=0.442, total=   0.1s
# [CV] splitter=random, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=entropy, score=0.415, total=   0.1s
# [CV] splitter=random, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=entropy, score=0.430, total=   0.1s
# [CV] splitter=random, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=entropy, score=0.451, total=   0.1s
# [CV] splitter=random, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=entropy, score=0.420, total=   0.1s
# [CV] splitter=random, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=entropy, score=0.420, total=   0.1s
# [CV] splitter=random, min_samples_leaf=8, max_features=log2, max_depth=10, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=8, max_features=log2, max_depth=10, criterion=entropy, score=0.394, total=   0.0s
# [CV] splitter=random, min_samples_leaf=8, max_features=log2, max_depth=10, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=8, max_features=log2, max_depth=10, criterion=entropy, score=0.394, total=   0.0s
# [CV] splitter=random, min_samples_leaf=8, max_features=log2, max_depth=10, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=8, max_features=log2, max_depth=10, criterion=entropy, score=0.398, total=   0.0s
# [CV] splitter=random, min_samples_leaf=8, max_features=log2, max_depth=10, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=8, max_features=log2, max_depth=10, criterion=entropy, score=0.397, total=   0.0s
# [CV] splitter=random, min_samples_leaf=8, max_features=log2, max_depth=10, criterion=entropy
# [CV]  splitter=random, min_samples_leaf=8, max_features=log2, max_depth=10, criterion=entropy, score=0.394, total=   0.0s
# [CV] splitter=best, min_samples_leaf=8, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=log2, max_depth=None, criterion=gini, score=0.431, total=   0.0s
# [CV] splitter=best, min_samples_leaf=8, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=log2, max_depth=None, criterion=gini, score=0.395, total=   0.0s
# [CV] splitter=best, min_samples_leaf=8, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=log2, max_depth=None, criterion=gini, score=0.397, total=   0.0s
# [CV] splitter=best, min_samples_leaf=8, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=log2, max_depth=None, criterion=gini, score=0.423, total=   0.0s
# [CV] splitter=best, min_samples_leaf=8, max_features=log2, max_depth=None, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=log2, max_depth=None, criterion=gini, score=0.394, total=   0.0s
# [CV] splitter=best, min_samples_leaf=8, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=sqrt, max_depth=10, criterion=gini, score=0.425, total=   0.1s
# [CV] splitter=best, min_samples_leaf=8, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=sqrt, max_depth=10, criterion=gini, score=0.424, total=   0.0s
# [CV] splitter=best, min_samples_leaf=8, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=sqrt, max_depth=10, criterion=gini, score=0.435, total=   0.1s
# [CV] splitter=best, min_samples_leaf=8, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=sqrt, max_depth=10, criterion=gini, score=0.451, total=   0.1s
# [CV] splitter=best, min_samples_leaf=8, max_features=sqrt, max_depth=10, criterion=gini
# [CV]  splitter=best, min_samples_leaf=8, max_features=sqrt, max_depth=10, criterion=gini, score=0.414, total=   0.1s
# [Parallel(n_jobs=1)]: Done 125 out of 125 | elapsed:   18.4s finished
# DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        min_samples_leaf=4, splitter='random')
# 0.4992611907866145
# 0.4902215965887022

# %%
text = input('Review : ')
text = cv.transform([text])
rs.predict(text)
# Out:
# Review : Worst course in the world the worst of the worst I hate the teacher of the course and the teacher is like a nerd and he sucks I hate him and the course the instructions are the worst in the world
# array([4])

# %%
grid = {
    "max_depth":[None,5,10,15,20,25],
    "criterion":["gini","entropy",],
    'splitter':['best','random'],
    "max_features":["auto","sqrt",'log2'],
    "min_samples_leaf":[1,2,4,6,8,10],
}
model_gs = DecisionTreeClassifier()
gs = GridSearchCV(estimator=model_gs,param_grid=grid,cv=5,verbose=25)
gs.fit(X_train,y_train)
print(gs.best_estimator_)
print(gs.score(X_test,y_test))
print(gs.best_score_)
pickle.dump(model_gs,open('./model_grid.pkl','wb'))
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=best
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=best, score=0.453, total=   1.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=best
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=best, score=0.442, total=   1.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=best
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.4s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=best, score=0.453, total=   1.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=best
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.7s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=best, score=0.440, total=   1.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=best
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    4.9s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=best, score=0.450, total=   1.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=random
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    6.3s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=random, score=0.445, total=   1.4s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=random
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    7.7s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=random, score=0.435, total=   1.5s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=random
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    9.2s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=random, score=0.455, total=   1.7s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=random
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   10.8s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=random, score=0.445, total=   1.6s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=random
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   12.5s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, splitter=random, score=0.449, total=   1.6s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=best
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   14.1s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=best, score=0.471, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=best
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   14.4s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=best, score=0.477, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=best
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   14.8s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=best, score=0.493, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=best
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   15.3s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=best, score=0.489, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=best
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   15.6s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=best, score=0.490, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=random
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   15.9s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=random, score=0.496, total=   0.5s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=random
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   16.4s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=random, score=0.486, total=   0.6s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=random
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   17.0s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=random, score=0.491, total=   0.5s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=random
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   17.5s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=random, score=0.494, total=   0.6s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=random
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   18.1s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, splitter=random, score=0.490, total=   0.6s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=best
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   18.6s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=best, score=0.480, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=best
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:   19.0s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=best, score=0.480, total=   0.6s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=best
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:   19.6s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=best, score=0.499, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=best, score=0.498, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=best
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:   20.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   20.2s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=best, score=0.477, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=random, score=0.480, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=random, score=0.497, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=random, score=0.503, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=random, score=0.490, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, splitter=random, score=0.491, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=best, score=0.486, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=best, score=0.485, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=best, score=0.501, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=best, score=0.499, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=best, score=0.495, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=random, score=0.470, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=random, score=0.478, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=random, score=0.512, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=random, score=0.480, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, splitter=random, score=0.514, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=best, score=0.487, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=best, score=0.481, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=best, score=0.482, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=best, score=0.483, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=best, score=0.495, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=random, score=0.469, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=random, score=0.478, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=random, score=0.485, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=random, score=0.458, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=8, splitter=random, score=0.484, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=best, score=0.498, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=best, score=0.487, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=best, score=0.495, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=best, score=0.492, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=best, score=0.499, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=random, score=0.463, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=random, score=0.501, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=random, score=0.488, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=random, score=0.471, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=10, splitter=random, score=0.503, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=best, score=0.443, total=   1.5s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=best, score=0.445, total=   1.5s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=best, score=0.456, total=   1.4s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=best, score=0.438, total=   1.6s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=best, score=0.453, total=   1.5s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=random, score=0.433, total=   1.7s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=random, score=0.450, total=   1.8s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=random, score=0.447, total=   1.6s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=random, score=0.450, total=   1.6s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, splitter=random, score=0.446, total=   1.6s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=best, score=0.489, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=best, score=0.481, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=best, score=0.498, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=best, score=0.493, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=best, score=0.498, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=random, score=0.482, total=   0.5s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=random, score=0.488, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=random, score=0.490, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=random, score=0.496, total=   0.8s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, splitter=random, score=0.483, total=   0.6s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=best, score=0.489, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=best, score=0.484, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=best, score=0.479, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=best, score=0.489, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=best, score=0.497, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=random, score=0.490, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=random, score=0.489, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=random, score=0.491, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=random, score=0.494, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, splitter=random, score=0.498, total=   0.7s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=best, score=0.496, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=best, score=0.498, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=best, score=0.504, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=best, score=0.497, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=best, score=0.473, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=random, score=0.469, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=random, score=0.483, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=random, score=0.496, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=random, score=0.493, total=   0.5s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=6, splitter=random, score=0.510, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=best, score=0.504, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=best, score=0.490, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=best, score=0.476, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=best, score=0.488, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=best, score=0.485, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=random, score=0.473, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=random, score=0.494, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=random, score=0.495, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=random, score=0.496, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=8, splitter=random, score=0.499, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=best, score=0.493, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=best, score=0.477, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=best, score=0.476, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=best, score=0.499, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=best, score=0.493, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=random, score=0.499, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=random, score=0.463, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=random, score=0.508, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=random, score=0.489, total=   0.4s
# [CV] criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=10, splitter=random, score=0.483, total=   0.5s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=best, score=0.416, total=   1.9s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=best, score=0.425, total=   1.9s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=best, score=0.434, total=   1.8s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=best, score=0.422, total=   1.7s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=best, score=0.427, total=   2.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=random, score=0.414, total=   2.3s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=random, score=0.415, total=   2.4s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=random, score=0.437, total=   2.5s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=random, score=0.418, total=   2.1s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, splitter=random, score=0.437, total=   3.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=best, score=0.412, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=best, score=0.474, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=best, score=0.473, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=best, score=0.453, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=best, score=0.414, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=random, score=0.441, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=random, score=0.428, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=random, score=0.413, total=   0.3s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=random, score=0.415, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, splitter=random, score=0.419, total=   0.2s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=best, score=0.414, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=best, score=0.453, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=best, score=0.402, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=best, score=0.448, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=best, score=0.409, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=random, score=0.395, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=random, score=0.414, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=random, score=0.405, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=random, score=0.395, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, splitter=random, score=0.405, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=best, score=0.395, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=best, score=0.408, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=best, score=0.394, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=best, score=0.425, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=best, score=0.394, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=random, score=0.398, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=random, score=0.394, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=random, score=0.399, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=random, score=0.398, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, splitter=random, score=0.394, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=best, score=0.426, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=best, score=0.394, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=best, score=0.423, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=best, score=0.395, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=best, score=0.397, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=random, score=0.395, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=random, score=0.395, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=random, score=0.394, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=random, score=0.395, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=8, splitter=random, score=0.395, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=best, score=0.404, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=best, score=0.400, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=best, score=0.398, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=best, score=0.407, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=best, score=0.439, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=random, score=0.400, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=random, score=0.394, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=random, score=0.398, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=random, score=0.397, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=10, splitter=random, score=0.394, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=best, score=0.425, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=best, score=0.455, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=best, score=0.458, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=best, score=0.453, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=best, score=0.409, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=random, score=0.410, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=random, score=0.406, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=random, score=0.404, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=random, score=0.396, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, splitter=random, score=0.403, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=best, score=0.411, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=best, score=0.426, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=best, score=0.458, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=best, score=0.409, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=best, score=0.426, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=random, score=0.409, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=random, score=0.402, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=random, score=0.413, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=random, score=0.408, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, splitter=random, score=0.402, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=best, score=0.446, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=best, score=0.417, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=best, score=0.405, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=best, score=0.444, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=best, score=0.435, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=random, score=0.400, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=random, score=0.418, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=random, score=0.412, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=random, score=0.400, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=4, splitter=random, score=0.423, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=best, score=0.456, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=best, score=0.408, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=best, score=0.429, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=best, score=0.417, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=best, score=0.428, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=random, score=0.401, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=random, score=0.410, total=   0.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=6, splitter=random
# ...
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=best, score=0.455, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=random, score=0.470, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=random, score=0.411, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=random, score=0.431, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=random, score=0.421, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, splitter=random, score=0.422, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=best, score=0.446, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=best, score=0.476, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=best, score=0.453, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=best, score=0.473, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=best, score=0.475, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=random, score=0.421, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=random, score=0.413, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=random, score=0.463, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=random, score=0.438, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=4, splitter=random, score=0.420, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=best, score=0.474, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=best, score=0.478, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=best, score=0.466, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=best, score=0.453, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=best, score=0.452, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=random, score=0.436, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=random, score=0.449, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=random, score=0.432, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=random, score=0.423, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=6, splitter=random, score=0.421, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=best, score=0.453, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=best, score=0.460, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=best, score=0.484, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=best, score=0.464, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=best, score=0.461, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=random, score=0.416, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=random, score=0.410, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=random, score=0.457, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=random, score=0.421, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, splitter=random, score=0.452, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=best, score=0.446, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=best, score=0.448, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=best, score=0.477, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=best, score=0.460, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=best, score=0.460, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=random, score=0.419, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=random, score=0.427, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=random, score=0.457, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=random, score=0.423, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=10, splitter=random, score=0.438, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=best, score=0.471, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=best, score=0.476, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=best, score=0.454, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=best, score=0.470, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=best
# [CV]  criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=best, score=0.470, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=random, score=0.432, total=   0.1s
# [CV] criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, splitter=random
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-cd55e886cbef> in <module>
#       8 model_gs = DecisionTreeClassifier()
#       9 gs = GridSearchCV(estimator=model_gs,param_grid=grid,cv=5,verbose=25)
# ---> 10 gs.fit(X_train,y_train)
#      11 print(gs.best_estimator_)
#      12 print(gs.score(X_test,y_test))
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
text = input('Review : ')
text = cv.transform([text])
model_rs.predict(text)
